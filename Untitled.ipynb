# %%
from __future__ import print_function

import copyreg as copy_reg
import random
import os
import time

import pickle as pkl
import torch
from torch import nn, optim
import numpy as np
import nltk

from models.vrnn import VRNN
from data_apis.data_utils import SWDADataLoader
from data_apis.SWDADialogCorpus import SWDADialogCorpus
import params

# %%
with open("data/cambridge_data/api_cambridge.txt", "rb") as fh:
    api = pkl.load(fh, encoding='latin1')

# %%
dial_corpus = api.get_dialog_corpus()

# %%
train_dial, labeled_dial, test_dial = dial_corpus.get("train"), dial_corpus.get("labeled"), dial_corpus.get("test")

# %%
train_dial[0]
# Out:
# [[[4, 12, 80, 57, 68, 55, 2, 21, 3, 32, 65, 14, 7, 2, 18, 3, 2, 19, 3, 6, 5],
#   [4,
#    26,
#    28,
#    115,
#    15,
#    14,
#    7,
#    2,
#    18,
#    3,
#    2,
#    19,
#    3,
#    32,
#    76,
#    2,
#    21,
#    3,
#    2,
#    20,
#    3,
#    6,
#    53,
#    9,
#    40,
#    23,
#    2,
#    20,
#    3,
#    94,
#    10,
#    5]],
#  [[4, 47, 12, 2, 41, 3, 63, 7, 2, 20, 3, 6, 5],
#   [4, 2, 17, 3, 8, 23, 2, 11, 3, 15, 48, 14, 7, 2, 18, 3, 2, 19, 3, 6, 5]],
#  [[4, 33, 8, 38, 2, 29, 3, 10, 5],
#   [4,
#    26,
#    2,
#    29,
#    3,
#    8,
#    2,
#    35,
#    3,
#    13,
#    54,
#    26,
#    49,
#    43,
#    12,
#    37,
#    51,
#    9,
#    58,
#    10,
#    5]],
#  [[4, 33, 8, 7, 2, 20, 3, 75, 76, 10, 5],
#   [4, 75, 76, 2, 11, 3, 2, 20, 3, 6, 5]],
#  [[4, 13, 32, 65, 33, 12, 226, 50, 27, 6, 96, 23, 299, 46, 5],
#   [4, 24, 9, 102, 119, 27, 83, 7, 106, 15, 78, 6, 5]]]

# %%
api.train_corpus[0]
# Out:
# [[[['<s>',
#     'i',
#     'need',
#     'to',
#     'find',
#     'an',
#     '[',
#     'value_pricerange',
#     ']',
#     'that',
#     's',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     'several',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     'that',
#     'serve',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'do',
#     'you',
#     'have',
#     'a',
#     '[',
#     'slot_food',
#     ']',
#     'preference',
#     '?',
#     '</s>']],
#   [['<s>',
#     'no',
#     'i',
#     '[',
#     'value_dontcare',
#     ']',
#     'about',
#     'the',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'located',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'what', 'is', 'their', '[', 'slot_address', ']', '?', '</s>'],
#    ['<s>',
#     'there',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     ',',
#     'it',
#     'there',
#     'anything',
#     'else',
#     'i',
#     'can',
#     'help',
#     'you',
#     'with',
#     '?',
#     '</s>']],
#   [['<s>',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_food',
#     ']',
#     'they',
#     'serve',
#     '?',
#     '</s>'],
#    ['<s>',
#     'they',
#     'serve',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     ',',
#     'that',
#     's',
#     'what',
#     'i',
#     'was',
#     'looking',
#     'for',
#     '.',
#     'thanks',
#     'a',
#     'lot',
#     '!',
#     '</s>'],
#    ['<s>',
#     'thank',
#     'you',
#     'very',
#     'much',
#     'for',
#     'using',
#     'the',
#     'cambridge',
#     'restaurant',
#     'system',
#     '.',
#     '</s>']]],
#  [[['<s>',
#     'i',
#     'am',
#     'looking',
#     'for',
#     'a',
#     'restaurant',
#     'that',
#     'is',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     'and',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     'no',
#     'restaurant',
#     'that',
#     'serve',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'how',
#     'about',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'value_name',
#     ']',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'and',
#     'is',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     '.',
#     'would',
#     'you',
#     'like',
#     'their',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>', 'their', '[', 'slot_phone', ']', 'please', '.', '</s>'],
#    ['<s>',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'what', 'is', 'the', '[', 'slot_area', ']', '?', '</s>'],
#    ['<s>',
#     'it',
#     'is',
#     'located',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '</s>']],
#   [['<s>', 'thank', 'you', 'for', 'your', 'help', '.', 'goodbye', '.', '</s>'],
#    ['<s>', 'goodbye', '.', '</s>']]],
#  [[['<s>',
#     ',',
#     'i',
#     'am',
#     'looking',
#     'for',
#     'an',
#     '[',
#     'value_pricerange',
#     ']',
#     'restaurant',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     'no',
#     'records',
#     'matching',
#     'your',
#     'request',
#     'for',
#     'an',
#     '[',
#     'value_pricerange',
#     ']',
#     'restaurant',
#     'serving',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'may',
#     'i',
#     'help',
#     'you',
#     'find',
#     'a',
#     'different',
#     'restaurant',
#     '?',
#     '</s>']],
#   [['<s>',
#     'what',
#     'about',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     '[',
#     'value_count',
#     ']',
#     'restaurant',
#     'matching',
#     'your',
#     'query',
#     '.',
#     '[',
#     'value_count',
#     ']',
#     'of',
#     'them',
#     'is',
#     '[',
#     'value_name',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'could',
#     'i',
#     'have',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'for',
#     '[',
#     'value_count',
#     ']',
#     'of',
#     'the',
#     'restaurant',
#     '?',
#     '</s>'],
#    ['<s>',
#     'there',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     'is',
#     'there',
#     'anything',
#     'else',
#     'i',
#     'can',
#     'help',
#     'you',
#     'with',
#     '?',
#     '</s>']],
#   [['<s>', 'thanks', ',', 'goodbye', '.', '</s>'],
#    ['<s>', 'thank', 'you', ',', 'goodbye', '.', '</s>']]],
#  [[['<s>',
#     'i',
#     'am',
#     'an',
#     '[',
#     'value_pricerange',
#     ']',
#     'restaurant',
#     'that',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'what',
#     'is',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'where',
#     'are',
#     'you',
#     'located',
#     '?',
#     'i',
#     'see',
#     '[',
#     'value_count',
#     ']',
#     'that',
#     'might',
#     'work',
#     'but',
#     'id',
#     'like',
#     'to',
#     'offer',
#     'the',
#     'closest',
#     '.',
#     '</s>']],
#   [['<s>',
#     'i',
#     '[',
#     'value_dontcare',
#     ']',
#     'about',
#     'the',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'an',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     'city',
#     '[',
#     'value_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'that',
#     'good',
#     ',',
#     'what',
#     'is',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'so',
#     'that',
#     'i',
#     'can',
#     'them',
#     '?',
#     '</s>'],
#    ['<s>',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'great', '!', 'thank', 'you', '.', 'goodbye', '.', '</s>'],
#    ['<s>', 'you', 'are', 'welcome', ',', 'goodbye', '.', '</s>']]],
#  [[['<s>',
#     'i',
#     'would',
#     'like',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'what',
#     '[',
#     'slot_food',
#     ']',
#     'does',
#     '[',
#     'value_name',
#     ']',
#     'serve',
#     '?',
#     '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'value_name',
#     ']',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'would',
#     'you',
#     'like',
#     'more',
#     'information',
#     '?',
#     '</s>']],
#   [['<s>',
#     'yes',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'for',
#     'the',
#     '?',
#     '</s>'],
#    ['<s>', 'they', 'are', 'located', 'at', '[', 'value_address', ']', '</s>']],
#   [['<s>',
#     'great',
#     '.',
#     'i',
#     'have',
#     'i',
#     'need',
#     ',',
#     'thank',
#     'you',
#     '</s>'],
#    ['<s>', 'you', 'are', 'welconme', '</s>']]],
#  [[['<s>',
#     'i',
#     'want',
#     'somewhere',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     'no',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     'city',
#     '.',
#     'can',
#     'i',
#     'help',
#     'you',
#     'with',
#     'a',
#     'different',
#     '[',
#     'slot_food',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>', 'how', '[', 'value_food', ']', '[', 'slot_food', ']', '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     '[',
#     'value_count',
#     ']',
#     'restaurant',
#     'meeting',
#     'your',
#     'criteria',
#     '.',
#     'what',
#     '[',
#     'slot_area',
#     ']',
#     'and',
#     '[',
#     'slot_pricerange',
#     ']',
#     'did',
#     'you',
#     'have',
#     'in',
#     'mind',
#     '?',
#     '</s>']],
#   [['<s>',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'value_name',
#     ']',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'they',
#     'are',
#     'located',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     'and',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'thank', 'you', '.', 'goodbye', '.', '</s>'],
#    ['<s>', 'goodbye', '</s>']]],
#  [[['<s>',
#     'is',
#     'there',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     'place',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     '[',
#     'value_count',
#     ']',
#     'restaurant',
#     'that',
#     'meet',
#     'your',
#     'specification',
#     '.',
#     '[',
#     'value_count',
#     ']',
#     'is',
#     '[',
#     'value_food',
#     ']',
#     'and',
#     'the',
#     'other',
#     'is',
#     '[',
#     'value_food',
#     ']',
#     '.',
#     'which',
#     'would',
#     'you',
#     'prefer',
#     '?',
#     '</s>']],
#   [['<s>',
#     '[',
#     'value_food',
#     ']',
#     ',',
#     'please',
#     '.',
#     'can',
#     'you',
#     'me',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     'their',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'what', 'is', 'the', '[', 'slot_phone', ']', 'please', '?', '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     's',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     'can',
#     'i',
#     'help',
#     'you',
#     'with',
#     'anything',
#     'else',
#     '?',
#     '</s>']],
#   [['<s>', 'no', 'that', 'will', 'be', 'it', '.', 'thank', 'you', '</s>'],
#    ['<s>', 'you', 'are', 'welcome', '.', 'goodbye', '.', '</s>']]],
#  [[['<s>',
#     'i',
#     'want',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'would',
#     'you',
#     'prefer',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'or',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>',
#     'i',
#     '[',
#     'value_dontcare',
#     ']',
#     '.',
#     'me',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'would',
#     'you',
#     'like',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>', 'yes', 'me', 'the', '[', 'slot_phone', ']', '.', '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'for',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', ',', 'thank', 'you', '!', 'goodbye', '!', '</s>'],
#    ['<s>', 'you', 'are', 'welcome', ',', 'goodbye', '.', '</s>']]],
#  [[['<s>',
#     'i',
#     'would',
#     'like',
#     'a',
#     'place',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'sorry',
#     'but',
#     'no',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     'is',
#     'found',
#     '.',
#     'can',
#     'i',
#     'provide',
#     'you',
#     'something',
#     'else',
#     '.',
#     '</s>']],
#   [['<s>',
#     'how',
#     'about',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'your',
#     'options',
#     'are',
#     '[',
#     'value_name',
#     ']',
#     ',',
#     '[',
#     'value_name',
#     ']',
#     ',',
#     '[',
#     'value_name',
#     ']',
#     ',',
#     'and',
#     '[',
#     'value_name',
#     ']',
#     '.',
#     'which',
#     '[',
#     'value_count',
#     ']',
#     'would',
#     'you',
#     'like',
#     'more',
#     'information',
#     'regarding',
#     '?',
#     '</s>']],
#   [['<s>',
#     'i',
#     'would',
#     'like',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     'of',
#     '[',
#     'value_name',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'located',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     'and',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     'can',
#     'i',
#     'help',
#     'you',
#     'with',
#     'anything',
#     'else',
#     'today',
#     '?',
#     '</s>']],
#   [['<s>', 'no', ',', 'thank', 'you', '.', '</s>'],
#    ['<s>', 'thank', 'you', ',', 'goodbye', '</s>']]],
#  [[['<s>',
#     'i',
#     'would',
#     'like',
#     'to',
#     'find',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     '[',
#     'value_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'can',
#     'you',
#     'me',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     ',',
#     '[',
#     'slot_phone',
#     ']',
#     ',',
#     'and',
#     '[',
#     'slot_postcode',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     ',',
#     '[',
#     'slot_postcode',
#     ']',
#     '[',
#     'value_postcode',
#     ']',
#     '.',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'thank',
#     'you',
#     'very',
#     'much',
#     'for',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'of',
#     'the',
#     '[',
#     'value_name',
#     ']',
#     '!',
#     '</s>'],
#    ['<s>', 'you', 'are', 'welcome', '.', 'goodbye', '!', '</s>']]],
#  [[['<s>', 'i', 'need', 'a', 'restaurant', '</s>'],
#    ['<s>', 'in', 'what', '[', 'slot_area', ']', '?', '</s>']],
#   [['<s>',
#     '[',
#     'value_area',
#     ']',
#     'and',
#     '[',
#     'value_pricerange',
#     ']',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     'several',
#     'restaurant',
#     'matches',
#     'in',
#     'this',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'would',
#     'you',
#     'like',
#     '[',
#     'value_food',
#     ']',
#     ',',
#     '[',
#     'value_food',
#     ']',
#     ',',
#     '[',
#     'value_food',
#     ']',
#     ',',
#     'or',
#     '[',
#     'value_food',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     'for',
#     'the',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     '</s>'],
#    ['<s>',
#     'here',
#     'you',
#     'go',
#     ',',
#     '[',
#     'value_phone',
#     ']',
#     ',',
#     '[',
#     'value_address',
#     ']',
#     '.',
#     'anything',
#     'else',
#     'today',
#     '?',
#     '</s>']],
#   [['<s>', 'no', ',', 'this', 'is', 'it', '.', 'thank', 'you', '</s>'],
#    ['<s>',
#     'wait',
#     '.',
#     'how',
#     'about',
#     'that',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     '?',
#     'where',
#     'is',
#     'it',
#     'located',
#     '?',
#     '</s>']],
#   [['<s>',
#     'is',
#     'there',
#     'a',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'i',
#     'am',
#     'sorry',
#     'no',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'thank', 'you', ',', 'goodbye', '.', '</s>'],
#    ['<s>', 'thank', 'you', 'goodbye', '</s>']]],
#  [[['<s>',
#     'i',
#     'would',
#     'like',
#     'to',
#     'find',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'an',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'that',
#     'meets',
#     'your',
#     'criteria',
#     '.',
#     'would',
#     'you',
#     'like',
#     'their',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>', '[', 'value_area', ']', '[', 'slot_area', ']', '.', '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'located',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'can',
#     'you',
#     'please',
#     'let',
#     'me',
#     'know',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'are',
#     'there',
#     '[',
#     'value_dontcare',
#     ']',
#     'other',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'price',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     'can',
#     'i',
#     'get',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'for',
#     'another',
#     '[',
#     'value_count',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'it',
#     'is',
#     'located',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'thank', 'you', 'goodbye', '.', '</s>'],
#    ['<s>', 'goodbye', '.', '</s>']]],
#  [[['<s>',
#     'i',
#     'would',
#     'like',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     'no',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     '.',
#     'would',
#     'you',
#     'like',
#     'to',
#     'change',
#     'your',
#     'query',
#     '?',
#     '</s>']],
#   [['<s>',
#     'how',
#     'about',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     '[',
#     'value_count',
#     ']',
#     'options',
#     'in',
#     '[',
#     'value_area',
#     ']',
#     'and',
#     '[',
#     'value_count',
#     ']',
#     'option',
#     'in',
#     '[',
#     'value_area',
#     ']',
#     '.',
#     'do',
#     'you',
#     'have',
#     'a',
#     'preference',
#     'on',
#     'the',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>',
#     'can',
#     'you',
#     'me',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'numbers',
#     'please',
#     '</s>'],
#    ['<s>',
#     'do',
#     'you',
#     'want',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'numbers',
#     'to',
#     '[',
#     'value_name',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>',
#     'okay',
#     ',',
#     'so',
#     'may',
#     'i',
#     'have',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'please',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     's',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'thank', 'you', ',', 'goodbye', '</s>'],
#    ['<s>', 'have', 'a', 'nice', 'day', '</s>']]],
#  [[['<s>',
#     'i',
#     'would',
#     'like',
#     'to',
#     'find',
#     'a',
#     'restaurant',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'im',
#     'sorry',
#     'there',
#     'are',
#     'no',
#     'restaurant',
#     'offering',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'in',
#     'your',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'is',
#     'there',
#     '[',
#     'value_dontcare',
#     ']',
#     'restaurant',
#     'that',
#     'serve',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'is',
#     'there',
#     'anything',
#     'else',
#     'i',
#     'can',
#     'help',
#     'you',
#     'with',
#     '?',
#     '</s>']],
#   [['<s>', 'what', 's', 'the', '[', 'slot_address', ']', '?', '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     's',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     '</s>']],
#   [['<s>', 'thank', 'you', ',', 'goodbye', '.', '</s>'],
#    ['<s>', 'thank', 'you', ',', 'goodbye', '.', '</s>']]],
#  [[['<s>',
#     'i',
#     'am',
#     'looking',
#     'for',
#     'a',
#     'restaurant',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'and',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'is',
#     'not',
#     'a',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     '.',
#     'would',
#     'you',
#     'like',
#     'a',
#     'different',
#     'restaurant',
#     '?',
#     '</s>']],
#   [['<s>',
#     'are',
#     'there',
#     '[',
#     'value_dontcare',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     '?',
#     '</s>'],
#    ['<s>',
#     'yes',
#     '.',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     'nice',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     ',',
#     '[',
#     'slot_phone',
#     ']',
#     ',',
#     'and',
#     '[',
#     'slot_postcode',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'located',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     'and',
#     'the',
#     '[',
#     'slot_postcode',
#     ']',
#     'is',
#     '[',
#     'value_postcode',
#     ']',
#     '.',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_count',
#     ']',
#     '.',
#     'may',
#     'i',
#     'help',
#     'you',
#     'with',
#     'anything',
#     'else',
#     '?',
#     '</s>']],
#   [['<s>', 'thank', 'you', 'goodbye', '.', '</s>'],
#    ['<s>', 'you', 'are', 'welcome', ',', 'goodbye', '.', '</s>']]],
#  [[['<s>',
#     'i',
#     'am',
#     'looking',
#     'for',
#     'a',
#     'restaurant',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     'no',
#     'restaurant',
#     'that',
#     'serve',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'are',
#     'you',
#     'interested',
#     'in',
#     'some',
#     'other',
#     '[',
#     'slot_food',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>',
#     'yes',
#     ',',
#     'how',
#     'about',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'i',
#     'will',
#     'also',
#     'need',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     ',',
#     '[',
#     'slot_phone',
#     ']',
#     ',',
#     'and',
#     '[',
#     'slot_postcode',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'is',
#     '[',
#     'value_count',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     'that',
#     'servies',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'it',
#     'is',
#     'and',
#     '[',
#     'value_pricerange',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     ',',
#     '[',
#     'slot_phone',
#     ']',
#     ',',
#     'and',
#     '[',
#     'slot_postcode',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'value_name',
#     ']',
#     's',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     ',',
#     'they',
#     'are',
#     'loated',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     ',',
#     'and',
#     'there',
#     '[',
#     'slot_postcode',
#     ']',
#     'is',
#     '.',
#     '[',
#     'value_postcode',
#     ']',
#     '</s>']],
#   [['<s>', 'thank', 'you', ',', 'goodbye', '.', '</s>'],
#    ['<s>',
#     'thank',
#     'you',
#     'for',
#     'using',
#     'our',
#     'system',
#     '.',
#     'goodbye',
#     '</s>']]],
#  [[['<s>',
#     'i',
#     'would',
#     'like',
#     'to',
#     'find',
#     'an',
#     '[',
#     'value_area',
#     ']',
#     'side',
#     'restaurant',
#     'that',
#     'is',
#     '[',
#     'value_pricerange',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     '[',
#     'value_count',
#     ']',
#     'restaurant',
#     'matching',
#     'your',
#     'request',
#     '.',
#     'what',
#     '[',
#     'slot_food',
#     ']',
#     'would',
#     'you',
#     'like',
#     '?',
#     '</s>']],
#   [['<s>',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'sound',
#     'good',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     ',',
#     'is',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     'and',
#     'is',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     '.',
#     'would',
#     'you',
#     'like',
#     'their',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>',
#     'what',
#     'is',
#     'their',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_postcode',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_count',
#     ']',
#     '[',
#     'value_address',
#     ']',
#     '[',
#     'value_postcode',
#     ']',
#     '</s>']],
#   [['<s>', 'thank', 'you', 'goodbye', '.', '</s>'],
#    ['<s>', 'thank', 'you', 'and', 'goodbye', '</s>']]],
#  [[['<s>',
#     ',',
#     'i',
#     'am',
#     'looking',
#     'for',
#     'a',
#     'restaurant',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'and',
#     '[',
#     'slot_postcode',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'to',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     'and',
#     'its',
#     '[',
#     'slot_postcode',
#     ']',
#     'is',
#     '[',
#     'value_postcode',
#     ']',
#     '</s>']],
#   [['<s>', 'okay', '.', 'thank', 'you', ',', 'goodbye', '.', '</s>'],
#    ['<s>',
#     'have',
#     'a',
#     'great',
#     'day',
#     'and',
#     'enjoy',
#     'your',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'thank', 'you', '.', '</s>'],
#    ['<s>', 'enjoy', 'your', 'day', '!', '</s>']]],
#  [[['<s>',
#     'i',
#     'need',
#     'to',
#     'find',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     ',',
#     'and',
#     'it',
#     'is',
#     'on',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'can',
#     'you',
#     'send',
#     'me',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'of',
#     'this',
#     'restaurant',
#     '?',
#     '</s>'],
#    ['<s>',
#     'yes',
#     ',',
#     'the',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'located',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     'and',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     'can',
#     'i',
#     'help',
#     'you',
#     'with',
#     'anything',
#     'else',
#     '?',
#     '</s>']],
#   [['<s>',
#     'no',
#     ',',
#     'that',
#     'will',
#     'do',
#     'it',
#     ',',
#     'thank',
#     'you',
#     'very',
#     'much',
#     '.',
#     '</s>'],
#    ['<s>', 'thank', 'you', '.', 'goodbye', '</s>']]],
#  [[['<s>',
#     'i',
#     'need',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     'of',
#     'a',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     '[',
#     'value_count',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'what',
#     '[',
#     'slot_food',
#     ']',
#     'would',
#     'you',
#     'like',
#     '?',
#     '</s>']],
#   [['<s>', 'i', '[', 'value_dontcare', ']', '.', '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'it',
#     's',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     ',',
#     'and',
#     'it',
#     's',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'can',
#     'you',
#     'tell',
#     'me',
#     'what',
#     '[',
#     'slot_food',
#     ']',
#     'they',
#     'serve',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'i',
#     'want',
#     '[',
#     'value_count',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     'priced',
#     'range',
#     '.',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_pricerange',
#     ']',
#     'of',
#     'restaurant',
#     '?',
#     '</s>'],
#    ['<s>',
#     'i',
#     'am',
#     'afraid',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     '[',
#     'value_pricerange',
#     ']',
#     '.',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'for',
#     '[',
#     'value_name',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'their',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'sorry',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_area',
#     ']',
#     'again',
#     '?',
#     '</s>'],
#    ['<s>',
#     'it',
#     'is',
#     'located',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '</s>']],
#   [['<s>', 'thank', 'you', ',', 'goodbye', '</s>'],
#    ['<s>', 'have', 'a', 'nice', 'day', '.', '</s>']]],
#  [[['<s>',
#     'is',
#     'there',
#     'a',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     'several',
#     'restaurant',
#     'located',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     ',',
#     'which',
#     '[',
#     'slot_food',
#     ']',
#     'do',
#     'you',
#     'prefer',
#     '?',
#     '</s>']],
#   [['<s>',
#     'i',
#     'would',
#     'like',
#     '[',
#     'value_count',
#     ']',
#     'serving',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     ',',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'in',
#     'the',
#     'city',
#     's',
#     '[',
#     'value_area',
#     ']',
#     '.',
#     'it',
#     'is',
#     '[',
#     'value_pricerange',
#     ']',
#     'but',
#     'very',
#     'classy',
#     '.',
#     'would',
#     'you',
#     'like',
#     'to',
#     'know',
#     'more',
#     'about',
#     'it',
#     '?',
#     '</s>']],
#   [['<s>',
#     'can',
#     'i',
#     'get',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     's',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     '.',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'thank', 'you', ',', 'goodbye', '.', '</s>'],
#    ['<s>', 'goodbye', 'and', 'have', 'a', 'nice', 'day', '.', '</s>']]],
#  [[['<s>',
#     'can',
#     'you',
#     'find',
#     'me',
#     'a',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     '?',
#     '</s>'],
#    ['<s>',
#     'i',
#     'am',
#     'sorry',
#     ',',
#     'i',
#     'cannot',
#     'find',
#     '[',
#     'value_dontcare',
#     ']',
#     'place',
#     'with',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'do',
#     'you',
#     'have',
#     'a',
#     'second',
#     'choice',
#     '?',
#     '</s>']],
#   [['<s>',
#     'yes',
#     ',',
#     'a',
#     'restaurant',
#     'serving',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'would',
#     'be',
#     'good',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     '[',
#     'value_count',
#     ']',
#     'restaurant',
#     'that',
#     'serve',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'do',
#     'you',
#     'have',
#     'an',
#     '[',
#     'slot_area',
#     ']',
#     'or',
#     '[',
#     'slot_pricerange',
#     ']',
#     'preference',
#     '?',
#     '</s>']],
#   [['<s>',
#     'i',
#     '[',
#     'value_dontcare',
#     ']',
#     'about',
#     'the',
#     '[',
#     'slot_pricerange',
#     ']',
#     ',',
#     'and',
#     'would',
#     'like',
#     '[',
#     'value_count',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'an',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '.',
#     'would',
#     'you',
#     'like',
#     'more',
#     'information',
#     '?',
#     '</s>']],
#   [['<s>',
#     'i',
#     'would',
#     'like',
#     'their',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     'please',
#     '.',
#     '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     ',',
#     'and',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     'can',
#     'i',
#     'find',
#     '[',
#     'value_dontcare',
#     ']',
#     'further',
#     'information',
#     'for',
#     'you',
#     '?',
#     '</s>']],
#   [['<s>', 'what', 'is', 'the', '[', 'slot_pricerange', ']', '?', '</s>'],
#    ['<s>', 'it', 'is', '[', 'value_pricerange', ']', '.', '</s>']],
#   [['<s>',
#     'that',
#     'you',
#     ',',
#     'that',
#     's',
#     'all',
#     'i',
#     'need',
#     'to',
#     'know',
#     '.',
#     '</s>'],
#    ['<s>', 'thank', 'you', ',', 'have', 'a', 'good', 'day', '!', '</s>']]],
#  [[['<s>',
#     ',',
#     'i',
#     'am',
#     'looking',
#     'for',
#     'a',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'on',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'i',
#     'can',
#     'help',
#     'you',
#     'with',
#     'that',
#     '.',
#     'it',
#     'looks',
#     'like',
#     'there',
#     'are',
#     'not',
#     '[',
#     'value_dontcare',
#     ']',
#     'restaurant',
#     'like',
#     'that',
#     'in',
#     'my',
#     'database',
#     '.',
#     'can',
#     'i',
#     'help',
#     'you',
#     'find',
#     'a',
#     'different',
#     'restaurant',
#     '?',
#     '</s>']],
#   [['<s>',
#     'is',
#     'there',
#     'a',
#     'restaurant',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'i',
#     'found',
#     'several',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'were',
#     'you',
#     'looking',
#     'for',
#     'an',
#     '[',
#     'value_pricerange',
#     ']',
#     'or',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     'restaurant',
#     '?',
#     '</s>']],
#   [['<s>', '[', 'value_pricerange', ']', '</s>'],
#    ['<s>',
#     'i',
#     'found',
#     'several',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     ',',
#     'can',
#     'i',
#     'help',
#     'you',
#     'with',
#     'anything',
#     'else',
#     '?',
#     '</s>']],
#   [['<s>',
#     'can',
#     'you',
#     'please',
#     'me',
#     'that',
#     '[',
#     'slot_phone',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'the',
#     'first',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     'on',
#     'the',
#     'database',
#     '.',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'for',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_food',
#     ']',
#     'they',
#     'serve',
#     '?',
#     '</s>'],
#    ['<s>',
#     'they',
#     'serve',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'can',
#     'you',
#     'please',
#     'me',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'located',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     '.',
#     'is',
#     'there',
#     'anything',
#     'else',
#     'i',
#     'can',
#     'help',
#     'you',
#     'with',
#     '?',
#     '</s>']],
#   [['<s>',
#     'no',
#     ',',
#     'thank',
#     'you',
#     ',',
#     'that',
#     'is',
#     'all',
#     'i',
#     'need',
#     '.',
#     'goodbye',
#     '!',
#     '</s>'],
#    ['<s>', 'thank', 'you', '.', 'good', 'day', '!', '</s>']]],
#  [[['<s>',
#     'i',
#     'want',
#     'something',
#     '[',
#     'value_pricerange',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'what',
#     '[',
#     'slot_food',
#     ']',
#     'would',
#     'you',
#     'like',
#     '?',
#     '</s>']],
#   [['<s>', 'i', '[', 'value_dontcare', ']', '.', '</s>'],
#    ['<s>',
#     'the',
#     'is',
#     'the',
#     '[',
#     'value_name',
#     ']',
#     'for',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'and',
#     'the',
#     '[',
#     'value_name',
#     ']',
#     'for',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'would',
#     'you',
#     'like',
#     'the',
#     'addresses',
#     '?',
#     '</s>']],
#   [['<s>',
#     'i',
#     'would',
#     'like',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'and',
#     '[',
#     'slot_address',
#     ']',
#     'for',
#     '[',
#     'value_name',
#     ']',
#     'please',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     's',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     'and',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     'is',
#     'there',
#     '[',
#     'value_dontcare',
#     ']',
#     'additional',
#     'info',
#     'i',
#     'can',
#     'help',
#     'you',
#     'find',
#     '?',
#     '</s>']],
#   [['<s>', 'thank', 'you', ',', 'goodbye', '.', '</s>'],
#    ['<s>',
#     'thank',
#     'you',
#     'for',
#     'using',
#     'our',
#     'service',
#     '.',
#     'have',
#     'a',
#     'great',
#     'day',
#     '!',
#     '</s>']]],
#  [[['<s>',
#     'i',
#     'am',
#     'looking',
#     'for',
#     'something',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     ',',
#     'could',
#     'you',
#     'get',
#     'me',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'and',
#     '[',
#     'slot_address',
#     ']',
#     'please',
#     '?',
#     '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'for',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     'it',
#     'is',
#     'located',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     '</s>']],
#   [['<s>', 'thank', 'you', 'goodbye', '.', '</s>'],
#    ['<s>', 'enjoy', 'your', 'meal', '!', '</s>']]],
#  [[['<s>',
#     'i',
#     'would',
#     'like',
#     'a',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'can',
#     'i',
#     'have',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'and',
#     '[',
#     'slot_address',
#     ']',
#     'please',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'restaurant',
#     'is',
#     'located',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     'and',
#     'its',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     'is',
#     'there',
#     'anything',
#     'else',
#     'i',
#     'can',
#     'help',
#     'you',
#     'with',
#     '?',
#     '</s>']],
#   [['<s>', 'thank', 'you', 'goodbye', '.', '</s>'],
#    ['<s>', 'thank', 'you', 'and', 'have', 'a', 'great', 'day', '!', '</s>']]],
#  [[['<s>',
#     'is',
#     'there',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'may',
#     'i',
#     'suggest',
#     '[',
#     'value_name',
#     ']',
#     ',',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>', 'is', 'there', 'anything', 'else', '?', '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restraunt',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     ',',
#     'and',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'thank', 'you', 'goodbye', '.', '</s>'],
#    ['<s>', 'thank', 'you', 'and', 'goodbye', '!', '</s>']]],
#  [[['<s>',
#     'i',
#     'am',
#     'looking',
#     'for',
#     'a',
#     'restaurant',
#     'that',
#     'is',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     'and',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     'results',
#     'matching',
#     'your',
#     'query',
#     '.',
#     'would',
#     'you',
#     'like',
#     '[',
#     'value_food',
#     ']',
#     ',',
#     '[',
#     'value_food',
#     ']',
#     ',',
#     '[',
#     'value_food',
#     ']',
#     ',',
#     'or',
#     '[',
#     'value_food',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>',
#     'let',
#     's',
#     'go',
#     'with',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'an',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'eatery',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'would',
#     'you',
#     'like',
#     '[',
#     'value_dontcare',
#     ']',
#     'additional',
#     'information',
#     'about',
#     'this',
#     'restaurant',
#     '?',
#     '</s>']],
#   [['<s>', '[', 'slot_address', ']', 'and', '[', 'slot_phone', ']', '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     '.',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'thank', 'you', ',', 'goodbye', '.', '</s>'],
#    ['<s>', 'you', 'are', 'welcome', ',', 'goodbye', '.', '</s>']]],
#  [[['<s>',
#     'i',
#     'want',
#     'some',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     'please',
#     '.',
#     '</s>'],
#    ['<s>',
#     'i',
#     'am',
#     'sorry',
#     'i',
#     'do',
#     'not',
#     'find',
#     '[',
#     'value_dontcare',
#     ']',
#     'restaurant',
#     'meeting',
# ...
#     ']',
#     '.',
#     'can',
#     'i',
#     'help',
#     'you',
#     'with',
#     'anything',
#     'else',
#     '?',
#     '</s>']],
#   [['<s>',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     'for',
#     '[',
#     'value_name',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     '.',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '</s>']],
#   [['<s>', 'thank', 'you', '</s>'],
#    ['<s>',
#     'you',
#     'are',
#     'welcome',
#     '.',
#     'is',
#     'there',
#     'anything',
#     'else',
#     '?',
#     '</s>']],
#   [['<s>', 'which', '[', 'slot_area', ']', 'it', 'is', 'in', '?', '</s>'],
#    ['<s>',
#     'it',
#     'is',
#     'located',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '</s>']],
#   [['<s>', 'no', ',', 'that', 'was', 'it', '.', 'bye', 'bye', '.', '</s>'],
#    ['<s>', 'goodbye', '</s>']]],
#  [[['<s>',
#     '.',
#     'i',
#     'want',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'is',
#     'not',
#     'a',
#     'restaurant',
#     'matching',
#     'your',
#     'request',
#     '.',
#     'would',
#     'you',
#     'like',
#     'a',
#     'different',
#     'restaurant',
#     '?',
#     '</s>']],
#   [['<s>',
#     'are',
#     'there',
#     '[',
#     'value_dontcare',
#     ']',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     '?',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     '[',
#     'value_count',
#     ']',
#     'listings',
#     'for',
#     'the',
#     'provided',
#     'criteria',
#     '.',
#     'do',
#     'you',
#     'prefer',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     'or',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>', 'i', '[', 'value_dontcare', ']', '.', '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'would',
#     'you',
#     'like',
#     'their',
#     '[',
#     'slot_address',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>', 'yes', 'please', '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'thank', 'you', ',', 'goodbye', '.', '</s>'],
#    ['<s>', 'thank', 'you', ',', 'goodbye', '.', '</s>']]],
#  [[['<s>',
#     'i',
#     'would',
#     'like',
#     'to',
#     'find',
#     'a',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     'part',
#     'of',
#     'the',
#     'city',
#     'that',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'would',
#     'you',
#     'like',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>', 'yes', 'and', 'the', '[', 'slot_address', ']', '.', '</s>'],
#    ['<s>',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     'and',
#     'their',
#     '[',
#     'slot_address',
#     ']',
#     'is',
#     '[',
#     'value_address',
#     ']',
#     '.',
#     '</s>']]],
#  [[['<s>',
#     'i',
#     'would',
#     'like',
#     'an',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     ',',
#     'please',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     'no',
#     'restaurant',
#     'serving',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'how',
#     'about',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'an',
#     '[',
#     'value_pricerange',
#     ']',
#     'restaurant',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'what', '[', 'slot_area', ']', 'is', 'this', 'in', '?', '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'located',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'is',
#     'there',
#     'anything',
#     'else',
#     'i',
#     'can',
#     'help',
#     'you',
#     'with',
#     '?',
#     '</s>']],
#   [['<s>',
#     'can',
#     'i',
#     'have',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'please',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     '</s>']]],
#  [[['<s>',
#     'is',
#     'there',
#     '[',
#     'value_dontcare',
#     ']',
#     'place',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     'here',
#     '?',
#     '</s>'],
#    ['<s>',
#     'i',
#     'am',
#     'sorry',
#     'there',
#     'are',
#     'no',
#     '[',
#     'value_food',
#     ']',
#     'place',
#     'in',
#     'the',
#     'city',
#     ',',
#     'is',
#     'there',
#     'another',
#     '[',
#     'slot_food',
#     ']',
#     'you',
#     'would',
#     'be',
#     'interested',
#     'in',
#     '?',
#     '</s>']],
#   [['<s>',
#     'i',
#     'am',
#     'interested',
#     'in',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     '[',
#     'value_count',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     '.',
#     'would',
#     'you',
#     'prefer',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     'or',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>',
#     'i',
#     '[',
#     'value_dontcare',
#     ']',
#     '.',
#     'can',
#     'you',
#     'me',
#     '[',
#     'value_count',
#     ']',
#     'of',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'sure',
#     ',',
#     '[',
#     'value_name',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     'and',
#     'its',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '</s>']],
#   [['<s>',
#     'i',
#     '[',
#     'value_dontcare',
#     ']',
#     'about',
#     'the',
#     '[',
#     'slot_pricerange',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'thank',
#     'you',
#     'for',
#     'using',
#     'the',
#     'cambridge',
#     'restaurant',
#     'system',
#     '.',
#     'goodbye',
#     '.',
#     '</s>']]],
#  [[['<s>',
#     ',',
#     'i',
#     'am',
#     'looking',
#     'for',
#     'a',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'what',
#     'is',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'located',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     'and',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'thank', 'you', '.', 'goodbye', '.', '</s>'],
#    ['<s>',
#     'you',
#     'are',
#     'very',
#     'welcome',
#     '.',
#     'have',
#     'a',
#     'good',
#     'night',
#     '.',
#     '</s>']]],
#  [[['<s>',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     'priced',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'restaurant',
#     '.',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     'no',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     '.',
#     'would',
#     'you',
#     'like',
#     'to',
#     'choose',
#     'another',
#     '[',
#     'slot_food',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>',
#     'yes',
#     ',',
#     'could',
#     'you',
#     'please',
#     'check',
#     'there',
#     'is',
#     'a',
#     '[',
#     'value_food',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     'there',
#     'are',
#     '[',
#     'value_count',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'listed',
#     '.',
#     '[',
#     'value_count',
#     ']',
#     'is',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     'and',
#     'the',
#     'rest',
#     'are',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'i',
#     'would',
#     'like',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     'of',
#     'the',
#     '[',
#     'value_count',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'i',
#     'am',
#     'sorry',
#     ',',
#     'it',
#     'appears',
#     'there',
#     'are',
#     'no',
#     'results',
#     'for',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'our',
#     'system',
#     'is',
#     'having',
#     'difficulty',
#     'of',
#     'some',
#     'sort',
#     '.',
#     '</s>']],
#   [['<s>',
#     'can',
#     'i',
#     'have',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     'of',
#     'a',
#     '[',
#     'value_food',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     '-',
#     'ly',
#     'priced',
#     '[',
#     'value_food',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     '.',
#     'it',
#     's',
#     'located',
#     'on',
#     '[',
#     'value_address',
#     ']',
#     ',',
#     'and',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>', 'thank', 'you', 'goodbye', '.', '</s>'],
#    ['<s>', 'thank', 'you', 'and', 'goodbye', '</s>']]],
#  [[['<s>',
#     'i',
#     'would',
#     'like',
#     'to',
#     'find',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     'restaurant',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '</s>'],
#    ['<s>',
#     'nothing',
#     'is',
#     'matching',
#     'your',
#     'request',
#     '.',
#     'i',
#     'am',
#     'sorry',
#     '.',
#     '</s>']],
#   [['<s>',
#     '.',
#     'could',
#     'you',
#     'help',
#     'me',
#     'find',
#     'some',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     'then',
#     '?',
#     '</s>'],
#    ['<s>',
#     'if',
#     'you',
#     'do',
#     'not',
#     'have',
#     'a',
#     'preference',
#     'of',
#     '[',
#     'slot_area',
#     ']',
#     ',',
#     'i',
#     'recommend',
#     '[',
#     'value_name',
#     ']',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '.',
#     '</s>']],
#   [['<s>',
#     'great',
#     ',',
#     'what',
#     'is',
#     'their',
#     '[',
#     'slot_phone',
#     ']',
#     'and',
#     '[',
#     'slot_address',
#     ']',
#     '?',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'located',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     'and',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     'is',
#     'there',
#     'anything',
#     'else',
#     'i',
#     'can',
#     'help',
#     'you',
#     'with',
#     '?',
#     '</s>']],
#   [['<s>', 'how', 'about', '[', 'value_food', ']', '?', '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'serves',
#     'great',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     'can',
#     'i',
#     'help',
#     'with',
#     'anything',
#     'else',
#     '?',
#     '</s>']],
#   [['<s>',
#     'no',
#     'that',
#     'is',
#     'all',
#     ',',
#     'thank',
#     'you',
#     'very',
#     'much',
#     '.',
#     'goodbye',
#     '.',
#     '</s>'],
#    ['<s>', 'you', 'are', 'very', 'welcome', '.', 'goodbye', ',', '</s>']]],
#  [[['<s>',
#     'i',
#     'am',
#     'looking',
#     'for',
#     'a',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     'that',
#     'serves',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'do',
#     'you',
#     'have',
#     'a',
#     'preference',
#     'as',
#     'to',
#     'what',
#     '[',
#     'slot_area',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>', 'i', '[', 'value_dontcare', ']', '.', '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'an',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     ',',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     'and',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '.',
#     'do',
#     'you',
#     'want',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     '?',
#     '</s>']],
#   [['<s>', '[', 'value_food', ']', '[', 'slot_food', ']', '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'an',
#     '[',
#     'value_food',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_area',
#     ']',
#     '[',
#     'slot_area',
#     ']',
#     'and',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     '[',
#     'slot_pricerange',
#     ']',
#     '.',
#     'how',
#     'does',
#     'that',
#     'sound',
#     '?',
#     '</s>']],
#   [['<s>', 'may', 'i', 'have', 'the', '[', 'slot_phone', ']', '?', '</s>'],
#    ['<s>',
#     'the',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     'is',
#     'there',
#     'anything',
#     'else',
#     'i',
#     'can',
#     'help',
#     'you',
#     'with',
#     '?',
#     '</s>']],
#   [['<s>', 'no', '.', 'thank', 'you', '.', '</s>'],
#    ['<s>', 'you', 'are', 'welcome', '.', '</s>']]],
#  [[['<s>',
#     'i',
#     'am',
#     'looking',
#     'for',
#     'a',
#     '[',
#     'value_pricerange',
#     ']',
#     'restaurant',
#     'serving',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     '.',
#     '</s>'],
#    ['<s>',
#     'what',
#     '[',
#     'slot_area',
#     ']',
#     'are',
#     'you',
#     'looking',
#     'at',
#     '?',
#     '</s>']],
#   [['<s>', 'i', '[', 'value_dontcare', ']', '.', '</s>'],
#    ['<s>',
#     'we',
#     'have',
#     '[',
#     'value_count',
#     ']',
#     'restaurant',
#     'in',
#     'the',
#     '[',
#     'value_pricerange',
#     ']',
#     'price',
#     'serving',
#     '[',
#     'value_food',
#     ']',
#     '[',
#     'slot_food',
#     ']',
#     ',',
#     'can',
#     'i',
#     'help',
#     'you',
#     'with',
#     'anything',
#     'else',
#     '?',
#     '</s>']],
#   [['<s>',
#     'yes',
#     'please',
#     '.',
#     'i',
#     'want',
#     'the',
#     '[',
#     'slot_address',
#     ']',
#     'and',
#     '[',
#     'slot_phone',
#     ']',
#     'of',
#     'of',
#     'them',
#     '.',
#     '</s>'],
#    ['<s>',
#     '[',
#     'value_name',
#     ']',
#     'is',
#     'located',
#     'at',
#     '[',
#     'value_address',
#     ']',
#     'and',
#     'its',
#     '[',
#     'slot_phone',
#     ']',
#     'is',
#     '[',
#     'value_phone',
#     ']',
#     '.',
#     'is',
#     'there',
#     'anything',
#     'else',
#     'i',
#     'can',
#     'help',
#     'you',
#     'with',
#     '?',
#     '</s>']],
#   [['<s>', 'thank', 'you', ',', 'goodbye', '</s>'],
#    ['<s>', 'you', 'are', 'welcome', '!', 'goodbye', '!', '</s>']]]]

# %%
# convert to numeric input outputs
train_loader = SWDADataLoader("Train", train_dial, params.max_utt_len,
                            params.max_dialog_len)
valid_loader = test_loader = SWDADataLoader("Test", test_dial,
                                        params.max_utt_len,
                                        params.max_dialog_len)
# Out:
# Max dialog len 8 and min dialog len 2 and avg len 4.113580
# Max dialog len 7 and min dialog len 2 and avg len 3.963235

# %%
# set random seeds
seed = params.seed
random.seed(seed)
np.random.seed(seed + 1)
torch.manual_seed(seed + 2)

# set device
use_cuda = params.use_cuda and torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %%
params.work_dir
# Out:
# 'working'

# %%
log_dir = os.path.join(params.work_dir, "run" + str(int(time.time())))

# %%
model = VRNN()
#model = model.cuda()

# %%
optimizer = optim.Adam(model.parameters(), lr=params.init_lr)

# %%
if train_loader.num_batch is None or train_loader.ptr >= train_loader.num_batch:
    train_loader.epoch_init(params.batch_size, shuffle=True)
# Out:
# Train begins with 25 batches with 5 left over samples

# %%
batch = train_loader.next_batch()

# %%
batch[3].shape
# Out:
# torch.Size([16, 10, 40])

# %%
embedding = nn.Embedding(params.max_vocab_cnt, params.embed_size)

# %%
embedding(batch[0]).shape
# Out:
# torch.Size([16, 10, 40, 300])

# %%
for epoch in range(1, params.max_epoch + 1):
    model.train()
    while True:
        optimizer.zero_grad()
        usr_input_sent, sys_input_sent, dialog_length_mask, usr_input_mask, sys_input_mask = train_loader.next_batch()
#         usr_input_sent = usr_input_sent.cuda()
#         sys_input_sent = sys_input_sent.cuda()
#         dialog_length_mask = dialog_length_mask.cuda()
#         usr_input_mask = usr_input_mask.cuda()
#         sys_input_mask = sys_input_mask.cuda()
        loss = model(usr_input_sent, sys_input_sent, dialog_length_mask, usr_input_mask, sys_input_mask)
        loss.backward()
        optimizer.step()
        print(loss)
# Out:
# vrnn  tensor([16063.1094, 16063.1094, 16063.1094,  ..., 11428.6426, 11428.6426,
#         11428.6426], grad_fn=<CatBackward>)
# vrnn  tensor(35494.3047, grad_fn=<DivBackward0>)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-81c34d572d90> in <module>
#      10 #         sys_input_mask = sys_input_mask.cuda()
#      11         loss = model(usr_input_sent, sys_input_sent, dialog_length_mask, usr_input_mask, sys_input_mask)
# ---> 12         loss.backward()
#      13         optimizer.step()
#      14         print(loss)
#
# D:\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     105                 products. Defaults to ``False``.
#     106         """
# --> 107         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     108
#     109     def register_hook(self, hook):
#
# D:\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# RuntimeError: Function MulBackward0 returned an invalid gradient at index 0 - expected type torch.FloatTensor but got torch.LongTensor

# %%
# # my fake code
# for p in model.parameters():
#     if p.requires_grad:
#          print(p.name, p.type())
